# %% [markdown]
# # 1. Install and Import Dependencies

# %%
# !pip install torch torchvision torchaudio -f https://download.pytorch.org/whl/lts/2.0/torch_lts.html
# Out:
# Looking in links: https://download.pytorch.org/whl/lts/2.0/torch_lts.html
# Requirement already satisfied: torch in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (2.0.1+cu118)
# Requirement already satisfied: torchvision in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (0.15.2+cu118)
# Requirement already satisfied: torchaudio in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (2.0.2+cu118)
# Requirement already satisfied: filelock in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\danie\appdata\roaming\python\python311\site-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from torch) (3.0)
# Requirement already satisfied: jinja2 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: numpy in c:\users\danie\appdata\roaming\python\python311\site-packages (from torchvision) (1.24.3)
# Requirement already satisfied: requests in c:\users\danie\appdata\roaming\python\python311\site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from torchvision) (10.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\danie\appdata\roaming\python\python311\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\danie\appdata\roaming\python\python311\site-packages (from requests->torchvision) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\danie\appdata\roaming\python\python311\site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\danie\appdata\roaming\python\python311\site-packages (from requests->torchvision) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\danie\appdata\roaming\python\python311\site-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from sympy->torch) (1.2.1)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# Requirement already satisfied: gitpython>=3.1.30 in c:\users\danie\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 5)) (3.1.32)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from -r requirements.txt (line 6)) (3.7.2)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\danie\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 7)) (1.24.3)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\danie\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 8)) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from -r requirements.txt (line 9)) (10.0.0)
# Requirement already satisfied: psutil in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from -r requirements.txt (line 10)) (5.9.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from -r requirements.txt (line 11)) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\danie\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 12)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\danie\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 13)) (1.11.1)
# Requirement already satisfied: thop>=0.1.1 in c:\users\danie\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from -r requirements.txt (line 15)) (2.0.1+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from -r requirements.txt (line 16)) (0.15.2+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from -r requirements.txt (line 17)) (4.65.0)
# Requirement already satisfied: ultralytics>=8.0.147 in c:\users\danie\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 18)) (8.0.147)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\danie\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 27)) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from -r requirements.txt (line 28)) (0.12.2)
# Requirement already satisfied: setuptools>=65.5.1 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from -r requirements.txt (line 42)) (68.0.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\danie\appdata\roaming\python\python311\site-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.10)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\danie\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\danie\appdata\roaming\python\python311\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\danie\appdata\roaming\python\python311\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\danie\appdata\roaming\python\python311\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\danie\appdata\roaming\python\python311\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2023.7.22)
# Requirement already satisfied: filelock in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\danie\appdata\roaming\python\python311\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.5.0)
# Requirement already satisfied: sympy in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.11.1)
# Requirement already satisfied: networkx in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.0)
# Requirement already satisfied: jinja2 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: colorama in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from tqdm>=4.64.0->-r requirements.txt (line 17)) (0.4.6)
# Requirement already satisfied: py-cpuinfo in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from ultralytics>=8.0.147->-r requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\danie\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\danie\appdata\roaming\python\python311\site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\danie\anaconda3\envs\pytorch_trial_0\lib\site-packages (from sympy->torch>=1.8.0->-r requirements.txt (line 15)) (1.2.1)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -----------------------
# absl-py                      1.4.0
# aiofiles                     22.1.0
# aiohttp                      3.8.5
# aiosignal                    1.3.1
# aiosqlite                    0.18.0
# anyio                        3.5.0
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# asn1crypto                   1.5.1
# asttokens                    2.0.5
# astunparse                   1.6.3
# async-timeout                4.0.3
# attrs                        22.1.0
# Babel                        2.11.0
# backcall                     0.2.0
# beautifulsoup4               4.12.2
# bleach                       4.1.0
# blis                         0.7.9
# boto3                        1.26.158
# botocore                     1.29.158
# brotlipy                     0.7.0
# cachetools                   5.3.1
# catalogue                    2.0.8
# certifi                      2023.7.22
# cffi                         1.15.1
# charset-normalizer           3.2.0
# click                        8.1.3
# colorama                     0.4.6
# comm                         0.1.2
# confection                   0.0.4
# contourpy                    1.1.0
# cramjam                      2.6.2
# cryptography                 39.0.1
# cvxopt                       1.3.1
# cvxpy                        1.3.2
# cycler                       0.11.0
# cymem                        2.0.7
# Cython                       3.0.0
# dataclasses-json             0.5.14
# debugpy                      1.5.1
# decorator                    5.1.1
# defusedxml                   0.7.1
# docx2txt                     0.8
# ecos                         2.0.12
# en-core-web-sm               3.5.0
# entrypoints                  0.4
# executing                    0.8.3
# fancyimpute                  0.7.0
# fastjsonschema               2.16.2
# fastparquet                  2023.4.0
# filelock                     3.9.0
# flatbuffers                  23.5.26
# fonttools                    4.40.0
# frozenlist                   1.4.0
# fsspec                       2023.6.0
# gast                         0.4.0
# gdown                        4.7.1
# gitdb                        4.0.10
# GitPython                    3.1.32
# google-auth                  2.22.0
# google-auth-oauthlib         1.0.0
# google-pasta                 0.2.0
# greenlet                     2.0.2
# grpcio                       1.57.0
# h5py                         3.9.0
# huggingface-hub              0.15.1
# idna                         3.4
# imbalanced-learn             0.11.0
# imblearn                     0.0
# iniconfig                    2.0.0
# ipykernel                    6.19.2
# ipython                      8.12.0
# ipython-genutils             0.2.0
# ipywidgets                   8.0.4
# jedi                         0.18.1
# Jinja2                       3.1.2
# jmespath                     1.0.1
# joblib                       1.2.0
# json5                        0.9.6
# jsonschema                   4.17.3
# jupyter                      1.0.0
# jupyter_client               7.4.9
# jupyter-console              6.6.3
# jupyter_core                 5.3.0
# jupyter-events               0.6.3
# jupyter-server               1.23.4
# jupyter_server_fileid        0.9.0
# jupyter_server_terminals     0.4.4
# jupyter_server_ydoc          0.8.0
# jupyter-ydoc                 0.2.4
# jupyterlab                   3.6.3
# jupyterlab-pygments          0.1.2
# jupyterlab_server            2.22.0
# jupyterlab-widgets           3.0.5
# keras                        2.13.1
# kiwisolver                   1.4.4
# knnimpute                    0.1.0
# langchain                    0.0.276
# langcodes                    3.3.0
# langsmith                    0.0.28
# libclang                     16.0.6
# lxml                         4.9.3
# Markdown                     3.4.4
# MarkupSafe                   2.1.3
# marshmallow                  3.20.1
# matplotlib                   3.7.2
# matplotlib-inline            0.1.6
# mistune                      0.8.4
# mpmath                       1.2.1
# multidict                    6.0.4
# murmurhash                   1.0.9
# mypy-extensions              1.0.0
# nbclassic                    0.5.5
# nbclient                     0.5.13
# nbconvert                    6.5.4
# nbformat                     5.7.0
# nest-asyncio                 1.5.6
# networkx                     3.0
# nlpaug                       1.1.11
# nltk                         3.8.1
# nose                         1.3.7
# notebook                     6.5.4
# notebook_shim                0.2.2
# numexpr                      2.8.5
# numpy                        1.24.3
# oauthlib                     3.2.2
# opencv-python                4.8.0.74
# opt-einsum                   3.3.0
# osqp                         0.6.3
# packaging                    23.1
# pandas                       2.0.3
# pandocfilters                1.5.0
# parso                        0.8.3
# pathy                        0.10.2
# patsy                        0.5.3
# pickleshare                  0.7.5
# Pillow                       10.0.0
# pip                          23.2.1
# platformdirs                 2.5.2
# pluggy                       1.2.0
# ply                          3.11
# preshed                      3.0.8
# prometheus-client            0.14.1
# prompt-toolkit               3.0.36
# protobuf                     4.24.1
# psutil                       5.9.0
# pure-eval                    0.2.2
# py-cpuinfo                   9.0.0
# pyarrow                      12.0.0
# pyasn1                       0.5.0
# pyasn1-modules               0.3.0
# pycocotools                  2.0
# pycparser                    2.21
# pydantic                     1.10.9
# Pygments                     2.15.1
# pyOpenSSL                    23.0.0
# pyparsing                    3.0.9
# pypdf                        3.15.4
# PyPDF2                       3.0.1
# PyQt5                        5.15.9
# pyqt5-plugins                5.15.9.2.3
# PyQt5-Qt5                    5.15.2
# PyQt5-sip                    12.11.0
# pyqt5-tools                  5.15.9.3.3
# pyrsistent                   0.18.0
# PySocks                      1.7.1
# pytest                       7.4.0
# python-dateutil              2.8.2
# python-dotenv                1.0.0
# python-json-logger           2.0.7
# pytz                         2022.7
# pywin32                      305.1
# pywinpty                     2.0.10
# PyYAML                       6.0.1
# pyzmq                        23.2.0
# qdldl                        0.1.7.post0
# qt5-applications             5.15.2.2.3
# qt5-tools                    5.15.2.1.3
# qtconsole                    5.4.2
# QtPy                         2.2.0
# redshift-connector           2.0.911
# regex                        2023.8.8
# requests                     2.31.0
# requests-oauthlib            1.3.1
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rsa                          4.9
# s3transfer                   0.6.1
# safetensors                  0.3.1
# scikit-learn                 1.2.2
# scipy                        1.11.1
# scramp                       1.4.4
# scs                          3.2.3
# seaborn                      0.12.2
# Send2Trash                   1.8.0
# sentence-transformers        2.2.2
# sentencepiece                0.1.99
# setuptools                   68.0.0
# sip                          6.6.2
# six                          1.16.0
# smart-open                   6.3.0
# smmap                        5.0.0
# sniffio                      1.2.0
# soupsieve                    2.4
# spacy                        3.5.3
# spacy-legacy                 3.0.12
# spacy-loggers                1.0.4
# SQLAlchemy                   2.0.20
# srsly                        2.4.6
# stack-data                   0.2.0
# statsmodels                  0.15.0.dev59+g01b19d7d1
# sympy                        1.11.1
# tenacity                     8.2.3
# tensorboard                  2.13.0
# tensorboard-data-server      0.7.1
# tensorflow                   2.13.0
# tensorflow-estimator         2.13.0
# tensorflow-intel             2.13.0
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.3.0
# terminado                    0.17.1
# tf-slim                      1.1.0
# thinc                        8.1.10
# thop                         0.1.1.post2209072238
# threadpoolctl                3.1.0
# tiktoken                     0.4.0
# tinycss2                     1.2.1
# tokenizers                   0.13.3
# toml                         0.10.2
# torch                        2.0.1+cu118
# torchaudio                   2.0.2+cu118
# torchvision                  0.15.2+cu118
# tornado                      6.2
# tqdm                         4.65.0
# traitlets                    5.7.1
# transformers                 4.30.1
# typer                        0.7.0
# typing_extensions            4.5.0
# typing-inspect               0.9.0
# tzdata                       2023.3
# ultralytics                  8.0.147
# urllib3                      1.26.16
# wasabi                       1.1.2
# wcwidth                      0.2.5
# webencodings                 0.5.1
# websocket-client             0.58.0
# Werkzeug                     2.3.7
# wget                         3.2
# wheel                        0.41.1
# widgetsnbextension           4.0.5
# win-inet-pton                1.1.0
# wrapt                        1.15.0
# xgboost                      1.7.6
# y-py                         0.5.9
# yarl                         1.9.2
# ypy-websocket                0.8.2
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
# !which python
# !pip --version
# !pip show torch
# Out:
# "which" non è riconosciuto come comando interno o esterno,
#  un programma eseguibile o un file batch.
# pip 23.2.1 from C:\Users\danie\anaconda3\envs\pytorch_trial_0\Lib\site-packages\pip (python 3.11)
#
# Name: torch
# Version: 2.0.1+cu118
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: C:\Users\danie\anaconda3\envs\pytorch_trial_0\Lib\site-packages
# Requires: filelock, jinja2, networkx, sympy, typing-extensions
# Required-by: sentence-transformers, thop, torchaudio, torchvision, ultralytics

# %%
# !source activate pytorch_trial_0
# Out:
# "source" non è riconosciuto come comando interno o esterno,
#  un programma eseguibile o un file batch.

# %% [markdown]
# # 2. Load Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\danie/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-10-26 Python-3.11.3 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3080 Laptop GPU, 16384MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): Conv(
#           (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (4): C3(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (5): Conv(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (6): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (7): Conv(
#           (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (8): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (9): SPPF(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         )
#         (10): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (11): Upsample(scale_factor=2.0, mode='nearest')
#         (12): Concat()
#         (13): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (14): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (15): Upsample(scale_factor=2.0, mode='nearest')
#         (16): Concat()
#         (17): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (18): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (19): Concat()
#         (20): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (21): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (22): Concat()
#         (23): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (24): Detect(
#           (m): ModuleList(
#             (0): Conv2d(128, 255, kernel_size=(1, 1), stride=(1, 1))
#             (1): Conv2d(256, 255, kernel_size=(1, 1), stride=(1, 1))
#             (2): Conv2d(512, 255, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# # 3. Make Detections with Images

# %%
img = 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e4/Cars_in_traffic_in_Auckland%2C_New_Zealand_-_copyright-free_photo_released_to_public_domain.jpg/800px-Cars_in_traffic_in_Auckland%2C_New_Zealand_-_copyright-free_photo_released_to_public_domain.jpg'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 533x800 2 persons, 28 cars, 5 trucks
# Speed: 220.7ms pre-process, 135.0ms inference, 41.1ms NMS per image at shape (1, 3, 448, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.render()
# Out:
# [array([[[251, 216, 174],
#          [254, 220, 175],
#          [246, 213, 168],
#          ...,
#          [127, 149, 146],
#          [ 67,  79,  55],
#          [ 64,  70,  34]],
#
#         [[235, 201, 156],
#          [233, 200, 155],
#          [221, 189, 142],
#          ...,
#          [120, 142, 140],
#          [ 82,  92,  67],
#          [ 46,  52,  16]],
#
#         [[252, 220, 171],
#          [245, 213, 164],
#          [212, 180, 131],
#          ...,
#          [135, 155, 154],
#          [ 66,  74,  50],
#          [ 58,  62,  25]],
#
#         ...,
#
#         [[ 61,  69,  80],
#          [ 64,  72,  83],
#          [ 61,  69,  80],
#          ...,
#          [ 47,  52,  56],
#          [ 48,  53,  57],
#          [ 49,  54,  58]],
#
#         [[ 56,  64,  75],
#          [ 72,  80,  91],
#          [ 70,  78,  89],
#          ...,
#          [ 48,  53,  57],
#          [ 48,  53,  57],
#          [ 50,  55,  59]],
#
#         [[ 64,  72,  83],
#          [ 76,  84,  95],
#          [ 63,  71,  82],
#          ...,
#          [ 49,  54,  58],
#          [ 49,  54,  58],
#          [ 50,  55,  59]]], dtype=uint8)]

# %% [markdown]
# # 4. Real Time Detections

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 8
#       5 # Make detections
#       6 results = model(frame)
# ----> 8 cv2.imshow('YOLO', np.squeeze(results.render()))
#      10 if cv2.waitKey(10) & 0xFF == ord('q'):
#      11     break
#
# File ~/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:815, in Detections.render(self, labels)
#     814 def render(self, labels=True):
# --> 815     self._run(render=True, labels=labels)  # render results
#     816     return self.ims
#
# File ~/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:780, in Detections._run(self, pprint, show, save, crop, render, labels, save_dir)
#     777 else:
#     778     s += '(no detections)'
# --> 780 im = Image.fromarray(im.astype(np.uint8)) if isinstance(im, np.ndarray) else im  # from np
#     781 if show:
#     782     if is_jupyter():
#
# File ~\anaconda3\envs\pytorch_trial_0\Lib\site-packages\PIL\Image.py:3093, in fromarray(obj, mode)
#    3090     else:
#    3091         obj = obj.tostring()
# -> 3093 return frombuffer(mode, size, obj, "raw", rawmode, 0, 1)
#
# File ~\anaconda3\envs\pytorch_trial_0\Lib\site-packages\PIL\Image.py:3009, in frombuffer(mode, size, data, decoder_name, *args)
#    3006         im.readonly = 1
#    3007         return im
# -> 3009 return frombytes(mode, size, data, decoder_name, args)
#
# File ~\anaconda3\envs\pytorch_trial_0\Lib\site-packages\PIL\Image.py:2950, in frombytes(mode, size, data, decoder_name, *args)
#    2947 if decoder_name == "raw" and args == ():
#    2948     args = mode
# -> 2950 im = new(mode, size)
#    2951 im.frombytes(data, decoder_name, args)
#    2952 return im
#
# File ~\anaconda3\envs\pytorch_trial_0\Lib\site-packages\PIL\Image.py:2914, in new(mode, size, color)
#    2912     im.palette = ImagePalette.ImagePalette()
#    2913     color = im.palette.getcolor(color)
# -> 2914 return im._new(core.fill(mode, size, color))
#
# KeyboardInterrupt:

# %% [markdown]
# # 5. Train from scratch

# %%
import uuid   # Unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['plasticglass', 'can','plasticbag']
number_imgs = 5

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        # Writes out image to file 
        cv2.imwrite(imgname, frame)
        
        # Render to the screen
        cv2.imshow('Image Collection', frame)
        
        # 2 second delay between captures
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
print(os.path.join(IMAGES_PATH, labels[0]+'.'+str(uuid.uuid1())+'.jpg'))

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)

# %%
# !git clone https://github.com/tzutalin/labelImg

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd
# Out:
# C:\Users\danie\Documents\dev\WallAI\TFODCourse

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github:  YOLOv5 is out of date by 6 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5  v7.0-224-g6262c7f Python-3.11.3 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3080 Laptop GPU, 16384MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5  runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to C:\Users\danie\AppData\Roaming\Ultralytics\Arial.ttf...
#
#   0%|          | 0.00/755k [00:00<?, ?B/s]
# 100%|##########| 755k/755k [00:00<00:00, 12.2MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
#
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
#   8%|7         | 1.08M/14.1M [00:00<00:01, 11.2MB/s]
#  23%|##3       | 3.25M/14.1M [00:00<00:00, 17.6MB/s]
#  52%|#####1    | 7.28M/14.1M [00:00<00:00, 28.7MB/s]
#  80%|#######9  | 11.3M/14.1M [00:00<00:00, 33.6MB/s]
# 100%|##########| 14.1M/14.1M [00:00<00:00, 32.2MB/s]
#
# Overriding model.yaml nc=80 with nc=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     21576  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7027720 parameters, 7027720 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
#
# train: Scanning C:\Users\danie\Documents\dev\WallAI\TFODCourse\yolov5\data\labels\train...:   0%|          | 0/251 [00:00<?, ?it/s]
# train: Scanning C:\Users\danie\Documents\dev\WallAI\TFODCourse\yolov5\data\labels\train... 1 images, 0 backgrounds, 0 corrupt:   0%|          | 1/251 [00:11<48:11, 11.56s/it]
# train: Scanning C:\Users\danie\Documents\dev\WallAI\TFODCourse\yolov5\data\labels\train... 25 images, 0 backgrounds, 0 corrupt:  10%|9         | 25/251 [00:11<01:14,  3.01it/s]
# train: Scanning C:\Users\danie\Documents\dev\WallAI\TFODCourse\yolov5\data\labels\train... 51 images, 0 backgrounds, 0 corrupt:  20%|##        | 51/251 [00:11<00:26,  7.41it/s]
# train: Scanning C:\Users\danie\Documents\dev\WallAI\TFODCourse\yolov5\data\labels\train... 76 images, 0 backgrounds, 0 corrupt:  30%|###       | 76/251 [00:11<00:13, 13.19it/s]
# train: Scanning C:\Users\danie\Documents\dev\WallAI\TFODCourse\yolov5\data\labels\train... 113 images, 0 backgrounds, 0 corrupt:  45%|####5     | 113/251 [00:11<00:05, 24.93it/s]
# train: Scanning C:\Users\danie\Documents\dev\WallAI\TFODCourse\yolov5\data\labels\train... 187 images, 0 backgrounds, 0 corrupt:  75%|#######4  | 187/251 [00:12<00:01, 57.03it/s]
# train: Scanning C:\Users\danie\Documents\dev\WallAI\TFODCourse\yolov5\data\labels\train... 251 images, 0 backgrounds, 0 corrupt: 100%|##########| 251/251 [00:12<00:00, 20.66it/s]
# train: WARNING  C:\Users\danie\Documents\dev\WallAI\TFODCourse\yolov5\data\images\train\can (8).jpg: corrupt JPEG restored and saved
# train: New cache created: C:\Users\danie\Documents\dev\WallAI\TFODCourse\yolov5\data\labels\train.cache
#
# val: Scanning C:\Users\danie\Documents\dev\WallAI\TFODCourse\yolov5\data\labels\test...:   0%|          | 0/68 [00:00<?, ?it/s]
# val: Scanning C:\Users\danie\Documents\dev\WallAI\TFODCourse\yolov5\data\labels\test... 1 images, 0 backgrounds, 0 corrupt:   1%|1         | 1/68 [00:11<13:07, 11.75s/it]
# val: Scanning C:\Users\danie\Documents\dev\WallAI\TFODCourse\yolov5\data\labels\test... 13 images, 0 backgrounds, 0 corrupt:  19%|#9        | 13/68 [00:11<00:36,  1.52it/s]
# val: Scanning C:\Users\danie\Documents\dev\WallAI\TFODCourse\yolov5\data\labels\test... 30 images, 0 backgrounds, 0 corrupt:  44%|####4     | 30/68 [00:11<00:08,  4.36it/s]
#     499/499      1.26G   0.008846   0.006729  9.981e-05         66        320:  81%|########1 | 13/16 [00:01<00:00,  7.83it/s]
#     499/499      1.26G   0.008948   0.006862  9.785e-05         82        320:  81%|########1 | 13/16 [00:01<00:00,  7.83it/s]
#     499/499      1.26G   0.008948   0.006862  9.785e-05         82        320:  94%|#########3| 15/16 [00:01<00:00,  7.63it/s]
#     499/499      1.26G   0.008907   0.006818  9.676e-05         37        320:  94%|#########3| 15/16 [00:01<00:00,  7.63it/s]
#     499/499      1.26G   0.008907   0.006818  9.676e-05         37        320: 100%|##########| 16/16 [00:01<00:00,  9.07it/s]
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/3 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  33%|###3      | 1/3 [00:00<00:00,  3.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  67%|######6   | 2/3 [00:00<00:00,  3.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 3/3 [00:00<00:00,  5.11it/s]
#                    all         68        130      0.953      0.907      0.922      0.811
#
# 500 epochs completed in 0.370 hours.
# Optimizer stripped from runs\train\exp2\weights\last.pt, 14.3MB
# Optimizer stripped from runs\train\exp2\weights\best.pt, 14.3MB
#
# Validating runs\train\exp2\weights\best.pt...
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
#
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:   0%|          | 0/3 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  33%|###3      | 1/3 [00:00<00:00,  3.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  67%|######6   | 2/3 [00:00<00:00,  2.60it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 3/3 [00:00<00:00,  3.83it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%|##########| 3/3 [00:00<00:00,  3.47it/s]
#                    all         68        130      0.982      0.894      0.932      0.822
#                    can         68         46      0.946          1       0.99       0.89
#             plasticbag         68         24          1      0.702       0.81      0.679
#          plasticbottle         68         60          1      0.981      0.994      0.896
# Results saved to runs\train\exp2

# %% [markdown]
# # 6. Load Custom Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp2/weights/best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\danie/.cache\torch\hub\master.zip
# YOLOv5  2023-10-26 Python-3.11.3 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3080 Laptop GPU, 16384MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data', 'images', 'awake.c9a24d48-e1f6-11eb-bbef-5cf3709bbcc6.jpg')

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 480x640 1 awake
# Speed: 16.0ms pre-process, 11.0ms inference, 2.0ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 10
#       6     results = model(frame)
#       8     cv2.imshow('YOLO', np.squeeze(results.render()))
# ---> 10     if cv2.waitKey(10) & 0xFF == ord('q'):
#      11         break
#      12 cap.release()
#
# KeyboardInterrupt:
